# %% [markdown]
# # Encoding Features Value

# %%
import ToolFunc as tool

# Table
dataInfos_path = 'dataInfos'
dataInfos = tool.read_dill(dataInfos_path)
# Out:
# dataInfos exists!

# %%
offset = 6
num_F = 95
for key1,value in dataInfos['AQ']['encoding2Type'].items():
    if(isinstance(value,dict)):
        for key2,values in value.items():
            if 1 in values:
                print(key1+'->'+key2+': '+str(values.index(1)+offset)+', '+str(values.index(1)+num_F))
            else:
                print(key1+'->'+key2+': '+str(0+offset)+', '+str(0+num_F))
# Out:
# NO2(ppb)->NO2(ppb): 6, 95
# NO2(ppb)->O3(ppb): 6, 95
# NO2(ppb)->PM2.5(ug/m3): 7, 96
# NO2(ppb)->SO2(ppb): 8, 97
# NO2(ppb)->city: 9, 98
# NO2(ppb)->day: 10, 99
# NO2(ppb)->month: 11, 100
# NO2(ppb)->station: 12, 101
# NO2(ppb)->weekDay: 13, 102
# NO2(ppb)->year: 14, 103
# O3(ppb)->NO2(ppb): 15, 104
# O3(ppb)->O3(ppb): 6, 95
# O3(ppb)->PM2.5(ug/m3): 16, 105
# O3(ppb)->SO2(ppb): 17, 106
# O3(ppb)->city: 18, 107
# O3(ppb)->day: 19, 108
# O3(ppb)->month: 20, 109
# O3(ppb)->station: 21, 110
# O3(ppb)->weekDay: 22, 111
# O3(ppb)->year: 23, 112
# PM2.5(ug/m3)->NO2(ppb): 24, 113
# PM2.5(ug/m3)->O3(ppb): 25, 114
# PM2.5(ug/m3)->PM2.5(ug/m3): 6, 95
# PM2.5(ug/m3)->SO2(ppb): 26, 115
# PM2.5(ug/m3)->city: 27, 116
# PM2.5(ug/m3)->day: 28, 117
# PM2.5(ug/m3)->month: 29, 118
# PM2.5(ug/m3)->station: 30, 119
# PM2.5(ug/m3)->weekDay: 31, 120
# PM2.5(ug/m3)->year: 32, 121
# SO2(ppb)->NO2(ppb): 33, 122
# SO2(ppb)->O3(ppb): 34, 123
# SO2(ppb)->PM2.5(ug/m3): 35, 124
# SO2(ppb)->SO2(ppb): 6, 95
# ...

# %%
offset = 6
num_F = 115
for key1,value in dataInfos['Transaction']['encoding2Type'].items():
    if(isinstance(value,dict)):
        for key2,values in value.items():
            if 1 in values:
                print(key1+'->'+key2+': '+str(values.index(1)+offset)+', '+str(values.index(1)+num_F))
            else:
                print(key1+'->'+key2+': '+str(0+offset)+', '+str(0+num_F))
# Out:
# address_code->address_code: 6, 115
# address_code->branch_name: 6, 115
# address_code->category: 7, 116
# address_code->gender: 8, 117
# address_code->invoice_price: 11, 120
# address_code->is_taiwan: 13, 122
# address_code->points_gained: 14, 123
# address_code->user_level: 15, 124
# address_code->invoice_month: 10, 119
# address_code->invoice_day: 9, 118
# address_code->invoice_weekday: 12, 121
# branch_name->address_code: 16, 125
# branch_name->branch_name: 6, 115
# branch_name->category: 17, 126
# branch_name->gender: 18, 127
# branch_name->invoice_price: 21, 130
# branch_name->is_taiwan: 23, 132
# branch_name->points_gained: 24, 133
# branch_name->user_level: 25, 134
# branch_name->invoice_month: 20, 129
# branch_name->invoice_day: 19, 128
# branch_name->invoice_weekday: 22, 131
# category->address_code: 26, 135
# category->branch_name: 27, 136
# category->category: 6, 115
# category->gender: 28, 137
# category->invoice_price: 31, 140
# category->is_taiwan: 33, 142
# ...
